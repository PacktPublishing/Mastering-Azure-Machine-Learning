# %%
from azureml.core import Workspace, Experiment

# Configure experiment
ws = Workspace.from_config()
exp = Experiment(workspace=ws, name='cifar10_cnn_experiment')

# %%
from azureml.core.compute import ComputeTarget, AmlCompute

# Create the cluster
config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2', max_nodes=4)
cluster = ComputeTarget.create(ws, 'cluster', config)
cluster.wait_for_completion(show_output=True)
# Out:
# Creating
# Succeeded
# AmlCompute wait for completion finished
# Minimum number of nodes requested have been provisioned

# %%
from azureml.train.estimator import Estimator

# Submit the training script to the cluster
estimator = Estimator(compute_target=cluster, source_directory='./code', entry_script='train.py', pip_packages=['keras==2.3.0', 'tensorflow==1.13.2'])
run = exp.submit(estimator)
run.wait_for_completion(show_output=True)
# Out:
# RunId: cifar10_cnn_experiment_1587672413_b906df08
# Web View: https://ml.azure.com/experiments/cifar10_cnn_experiment/runs/cifar10_cnn_experiment_1587672413_b906df08?wsid=/subscriptions/21dc412b-d9eb-42e7-8317-55bc8eb10cf5/resourcegroups/packt-mastering-azure-machine-learning/workspaces/packt
#
# Streaming azureml-logs/55_azureml-execution-tvmps_252902eed4e32561ee05c0fbe978547aadc07cb2fae7069d9502f3167a627a6d_d.txt
# ========================================================================================================================
#
# 2020-04-23T20:14:47Z Starting output-watcher...
# 2020-04-23T20:14:47Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_3cd72ab6bce97df95ddb7b8fe193e306
# a1298f4ce990: Pulling fs layer
# 04a3282d9c4b: Pulling fs layer
# 9b0d3db6dc03: Pulling fs layer
# 8269c605f3f1: Pulling fs layer
# 6504d449e70c: Pulling fs layer
# 4e38f320d0d4: Pulling fs layer
# b0a763e8ee03: Pulling fs layer
# 11917a028ca4: Pulling fs layer
# a6c378d11cbf: Pulling fs layer
# 6cc007ad9140: Pulling fs layer
# 6c1698a608f3: Pulling fs layer
# 811860f26b9d: Pulling fs layer
# 495d26ae9741: Pulling fs layer
# 0fba3f0d7e26: Pulling fs layer
# b1c91e0a74a3: Pulling fs layer
# af0c6426cb3c: Pulling fs layer
# a4d3765db881: Pulling fs layer
# 6cc007ad9140: Waiting
# 6c1698a608f3: Waiting
# 811860f26b9d: Waiting
# 495d26ae9741: Waiting
# 0fba3f0d7e26: Waiting
# b1c91e0a74a3: Waiting
# af0c6426cb3c: Waiting
# a4d3765db881: Waiting
# 8269c605f3f1: Waiting
# 6504d449e70c: Waiting
# 4e38f320d0d4: Waiting
# b0a763e8ee03: Waiting
# 11917a028ca4: Waiting
# a6c378d11cbf: Waiting
# 04a3282d9c4b: Verifying Checksum
# 04a3282d9c4b: Download complete
# 9b0d3db6dc03: Verifying Checksum
# 9b0d3db6dc03: Download complete
# 8269c605f3f1: Verifying Checksum
# 8269c605f3f1: Download complete
# a1298f4ce990: Verifying Checksum
# a1298f4ce990: Download complete
# 6504d449e70c: Verifying Checksum
# 6504d449e70c: Download complete
# b0a763e8ee03: Verifying Checksum
# b0a763e8ee03: Download complete
# 4e38f320d0d4: Verifying Checksum
# 4e38f320d0d4: Download complete
# 6cc007ad9140: Verifying Checksum
# 6cc007ad9140: Download complete
# 11917a028ca4: Verifying Checksum
# 11917a028ca4: Download complete
# 811860f26b9d: Verifying Checksum
# 811860f26b9d: Download complete
# 6c1698a608f3: Verifying Checksum
# 6c1698a608f3: Download complete
# 495d26ae9741: Verifying Checksum
# 495d26ae9741: Download complete
# 0fba3f0d7e26: Verifying Checksum
# 0fba3f0d7e26: Download complete
# a6c378d11cbf: Verifying Checksum
# a6c378d11cbf: Download complete
# b1c91e0a74a3: Verifying Checksum
# b1c91e0a74a3: Download complete
# a4d3765db881: Verifying Checksum
# a4d3765db881: Download complete
# a1298f4ce990: Pull complete
# 04a3282d9c4b: Pull complete
# 9b0d3db6dc03: Pull complete
# 8269c605f3f1: Pull complete
# af0c6426cb3c: Verifying Checksum
# af0c6426cb3c: Download complete
# 6504d449e70c: Pull complete
# 4e38f320d0d4: Pull complete
# b0a763e8ee03: Pull complete
# 11917a028ca4: Pull complete
# a6c378d11cbf: Pull complete
# 6cc007ad9140: Pull complete
# 6c1698a608f3: Pull complete
# 811860f26b9d: Pull complete
# 495d26ae9741: Pull complete
# 0fba3f0d7e26: Pull complete
# b1c91e0a74a3: Pull complete
# af0c6426cb3c: Pull complete
# a4d3765db881: Pull complete
# Digest: sha256:760de135f293652a6697e0a171d7e34e9c93b130782c21ceb439823adba49ab1
# Status: Downloaded newer image for packtc4e2eded.azurecr.io/azureml/azureml_3cd72ab6bce97df95ddb7b8fe193e306:latest
#
# Streaming azureml-logs/65_job_prep-tvmps_252902eed4e32561ee05c0fbe978547aadc07cb2fae7069d9502f3167a627a6d_d.txt
# ===============================================================================================================
#
# bash: /azureml-envs/azureml_48faf8fe28ffc1fe622dd2418b6bf59f/lib/libtinfo.so.5: no version information available (required by bash)
# Starting job_prep.py script
# Starting job preparation. Current time:2020-04-23T20:16:16.726131
# Extracting the control code.
# fetching and extracting the control code on master node.
# Retrieving project from snapshot: e41d7e7e-7a7c-4d5f-b054-83bb930fd21e
# Starting the daemon thread to refresh tokens in background for process with pid = 81
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# bash: /azureml-envs/azureml_48faf8fe28ffc1fe622dd2418b6bf59f/lib/libtinfo.so.5: no version information available (required by bash)
# bash: /azureml-envs/azureml_48faf8fe28ffc1fe622dd2418b6bf59f/lib/libtinfo.so.5: no version information available (required by bash)
# Starting the daemon thread to refresh tokens in background for process with pid = 132
# Entering Run History Context Manager.
# Preparing to call script [ train.py ] with arguments: []
# After variable expansion, calling script [ train.py ] with arguments: []
#
# Using TensorFlow backend.
# /azureml-envs/azureml_48faf8fe28ffc1fe622dd2418b6bf59f/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /azureml-envs/azureml_48faf8fe28ffc1fe622dd2418b6bf59f/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /azureml-envs/azureml_48faf8fe28ffc1fe622dd2418b6bf59f/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /azureml-envs/azureml_48faf8fe28ffc1fe622dd2418b6bf59f/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /azureml-envs/azureml_48faf8fe28ffc1fe622dd2418b6bf59f/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /azureml-envs/azureml_48faf8fe28ffc1fe622dd2418b6bf59f/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
#  8192/10000 [=======================>......] - ETA: 0s
#  8320/10000 [=======================>......] - ETA: 0s
#  8448/10000 [========================>.....] - ETA: 0s
#  8576/10000 [========================>.....] - ETA: 0s
#  8704/10000 [=========================>....] - ETA: 0s
#  8832/10000 [=========================>....] - ETA: 0s
#  8960/10000 [=========================>....] - ETA: 0s
#  9056/10000 [==========================>...] - ETA: 0s
#  9184/10000 [==========================>...] - ETA: 0s
#  9312/10000 [==========================>...] - ETA: 0s
#  9440/10000 [===========================>..] - ETA: 0s
#  9568/10000 [===========================>..] - ETA: 0s
#  9696/10000 [============================>.] - ETA: 0s
#  9792/10000 [============================>.] - ETA: 0s
#  9920/10000 [============================>.] - ETA: 0s
# 10000/10000 [==============================] - 5s 463us/step
# Test loss: 1.1463993593215942
# Test accuracy: 0.6029000282287598
#
#
# The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 2 items cleaning up...
# Cleanup took 0.4378807544708252 seconds
# Starting the daemon thread to refresh tokens in background for process with pid = 132
#
# Streaming azureml-logs/75_job_post-tvmps_252902eed4e32561ee05c0fbe978547aadc07cb2fae7069d9502f3167a627a6d_d.txt
# ===============================================================================================================
#
# bash: /azureml-envs/azureml_48faf8fe28ffc1fe622dd2418b6bf59f/lib/libtinfo.so.5: no version information available (required by bash)
# Starting job release. Current time:2020-04-23T20:28:52.210021
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 960
# Job release is complete. Current time:2020-04-23T20:28:54.100465
#
# Execution Summary
# =================
# RunId: cifar10_cnn_experiment_1587672413_b906df08
# Web View: https://ml.azure.com/experiments/cifar10_cnn_experiment/runs/cifar10_cnn_experiment_1587672413_b906df08?wsid=/subscriptions/21dc412b-d9eb-42e7-8317-55bc8eb10cf5/resourcegroups/packt-mastering-azure-machine-learning/workspaces/packt
# {'runId': 'cifar10_cnn_experiment_1587672413_b906df08',
#  'target': 'cluster',
#  'status': 'Completed',
#  'startTimeUtc': '2020-04-23T20:14:42.075819Z',
#  'endTimeUtc': '2020-04-23T20:29:05.247739Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': '8dbad504-5678-4aa0-b4c0-60dd2a36f82e',
#   'azureml.git.repository_uri': 'git@github.com:chaosmail/mastering-azure-machine-learning.git',
#   'mlflow.source.git.repoURL': 'git@github.com:chaosmail/mastering-azure-machine-learning.git',
#   'azureml.git.branch': 'master',
#   'mlflow.source.git.branch': 'master',
#   'azureml.git.commit': 'b32390f7a67460a7639208f9324530c4dd9dcc9a',
#   'mlflow.source.git.commit': 'b32390f7a67460a7639208f9324530c4dd9dcc9a',
#   'azureml.git.dirty': 'False',
#   'AzureML.DerivedImageName': 'azureml/azureml_3cd72ab6bce97df95ddb7b8fe193e306',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [],
#  'runDefinition': {'script': 'train.py',
#   'useAbsolutePath': False,
#   'arguments': [],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'cluster',
#   'dataReferences': {},
#   'data': {},
#   'jobName': None,
#   'maxRunDurationSeconds': None,
#   'nodeCount': 1,
#   'environment': {'name': 'Experiment cifar10_cnn_experiment Environment',
#    'version': 'Autosave_2020-04-22T22:22:39Z_e6888ce3',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['conda-forge'],
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-defaults', 'keras==2.3.0', 'tensorflow==1.13.2']}],
#      'name': 'azureml_48faf8fe28ffc1fe622dd2418b6bf59f'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04',
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': True,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': False},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': 1},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': True,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}}},
#  'logFiles': {'azureml-logs/55_azureml-execution-tvmps_252902eed4e32561ee05c0fbe978547aadc07cb2fae7069d9502f3167a627a6d_d.txt': 'https://packt6644853404.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar10_cnn_experiment_1587672413_b906df08/azureml-logs/55_azureml-execution-tvmps_252902eed4e32561ee05c0fbe978547aadc07cb2fae7069d9502f3167a627a6d_d.txt?sv=2019-02-02&sr=b&sig=UCVKy0Sgi93qCCqD8E%2FSv6I7L1GdVqJo%2FbgUgrAUW00%3D&st=2020-04-23T20%3A19%3A06Z&se=2020-04-24T04%3A29%3A06Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_252902eed4e32561ee05c0fbe978547aadc07cb2fae7069d9502f3167a627a6d_d.txt': 'https://packt6644853404.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar10_cnn_experiment_1587672413_b906df08/azureml-logs/65_job_prep-tvmps_252902eed4e32561ee05c0fbe978547aadc07cb2fae7069d9502f3167a627a6d_d.txt?sv=2019-02-02&sr=b&sig=OvgXhz8%2BZXF7dOukgunCP6Fb6qeH0LZPcb%2F%2FDaLvq%2FU%3D&st=2020-04-23T20%3A19%3A06Z&se=2020-04-24T04%3A29%3A06Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://packt6644853404.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar10_cnn_experiment_1587672413_b906df08/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=pdQDmGuCDRlvUnoTW11t6PJii6RJjqn8LkZiF6qoSuk%3D&st=2020-04-23T20%3A19%3A06Z&se=2020-04-24T04%3A29%3A06Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_252902eed4e32561ee05c0fbe978547aadc07cb2fae7069d9502f3167a627a6d_d.txt': 'https://packt6644853404.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar10_cnn_experiment_1587672413_b906df08/azureml-logs/75_job_post-tvmps_252902eed4e32561ee05c0fbe978547aadc07cb2fae7069d9502f3167a627a6d_d.txt?sv=2019-02-02&sr=b&sig=nHWyg8FXehnvAdJzayZyk8FP6pIXWy8paocJ8KuWwTM%3D&st=2020-04-23T20%3A19%3A06Z&se=2020-04-24T04%3A29%3A06Z&sp=r',
#   'azureml-logs/process_info.json': 'https://packt6644853404.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar10_cnn_experiment_1587672413_b906df08/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=Odx8vNeuQBy5yJW1Fo%2B0W9o998hRJv%2FikXtrYHm%2BrLw%3D&st=2020-04-23T20%3A19%3A06Z&se=2020-04-24T04%3A29%3A06Z&sp=r',
#   'azureml-logs/process_status.json': 'https://packt6644853404.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar10_cnn_experiment_1587672413_b906df08/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=GYaUJ73eGXPAWIADW1NuP98FYUzjKTHAC%2FQfw9M373U%3D&st=2020-04-23T20%3A19%3A06Z&se=2020-04-24T04%3A29%3A06Z&sp=r',
#   'logs/azureml/132_azureml.log': 'https://packt6644853404.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar10_cnn_experiment_1587672413_b906df08/logs/azureml/132_azureml.log?sv=2019-02-02&sr=b&sig=Y8As7Lthdtq4HL4EAH0d%2BRqBW9MvNqKiQzJIrGLKkJI%3D&st=2020-04-23T20%3A19%3A06Z&se=2020-04-24T04%3A29%3A06Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://packt6644853404.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar10_cnn_experiment_1587672413_b906df08/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=jIE%2BKmCkEZVU9LdD%2FpeQGVT%2BExZih%2Fug1cu44Ut%2FgRI%3D&st=2020-04-23T20%3A19%3A06Z&se=2020-04-24T04%3A29%3A06Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://packt6644853404.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar10_cnn_experiment_1587672413_b906df08/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=XeCrDdVZSnWRD07dBsa2cdl2KKT57%2B5KuRZaT1alGpw%3D&st=2020-04-23T20%3A19%3A06Z&se=2020-04-24T04%3A29%3A06Z&sp=r'}}

# %%
cluster.delete()
